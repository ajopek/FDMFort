# %%
import pandas as pan
import matplotlib.pyplot as plot

# %%
# Load data
data4 = pan.read_table('../result4.data', sep=r"\s+", header=0)
data8 = pan.read_table('../result8.data', sep=r"\s+", header=0)
data16 = pan.read_table('../result16.data', sep=r"\s+", header=0)

# %%
data4.sort_values(by='n').plot(figsize=(15, 10), x='n', y='error')
plot.show()

# %%
data8.sort_values(by='n').plot(figsize=(15, 10), x='n', y='error')
plot.show()

# %%
data16.sort_values(by='n').plot(figsize=(15, 10), x='n', y='error')
plot.show()
